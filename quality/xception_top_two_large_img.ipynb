# %% [markdown]
# # ImageNet Fine Tuning Binary Classification With Large Images
# This experiment will involve classifying high- and medium-quality images using a fine-tuning the pretrained Xception model on larger images (256x256). Performance will be compared to both the binary high-low and multiclass classifiers.

# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Sun Sep  8 21:42:39 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-32GB           On  |   00000000:07:00.0 Off |                    0 |
# | N/A   37C    P0             69W /  300W |       1MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in ./.local/lib/python3.11/site-packages (24.2)

# %%
# !pip install tensorflow[and-cuda]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow[and-cuda] in ./.local/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: packaging in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.31.0)
# Requirement already satisfied: setuptools in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.26.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.3.4.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.3.101 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.101)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.3.107 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.3.107 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.3.101 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.101)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.7.29 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (8.9.7.29)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.12.1 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (11.0.12.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.4.107 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (10.3.4.107)
# Requirement already satisfied: nvidia-cusolver-cu12==11.5.4.101 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (11.5.4.101)
# Requirement already satisfied: nvidia-cusparse-cu12==12.2.0.103 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.2.0.103)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.3.101 in ./.local/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.3.101)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.41.2)
# Requirement already satisfied: rich in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow[and-cuda]) (13.3.5)
# Requirement already satisfied: namex in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow[and-cuda]) (0.0.8)
# Requirement already satisfied: optree in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow[and-cuda]) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow[and-cuda]) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow[and-cuda]) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow[and-cuda]) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow[and-cuda]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow[and-cuda]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow[and-cuda]) (0.1.0)

# %%
# !pip install --upgrade keras-cv tensorflow
# !pip install --upgrade keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-cv in ./.local/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: tensorflow in ./.local/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: packaging in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras-cv) (23.2)
# Requirement already satisfied: absl-py in ./.local/lib/python3.11/site-packages (from keras-cv) (2.1.0)
# Requirement already satisfied: regex in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras-cv) (2023.10.3)
# Requirement already satisfied: tensorflow-datasets in ./.local/lib/python3.11/site-packages (from keras-cv) (4.9.6)
# Requirement already satisfied: keras-core in ./.local/lib/python3.11/site-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in ./.local/lib/python3.11/site-packages (from keras-cv) (0.2.9)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.local/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.11/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.11/site-packages (from tensorflow) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.local/lib/python3.11/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (2.2.3)
# Requirement already satisfied: tqdm in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from kagglehub->keras-cv) (4.65.0)
# Requirement already satisfied: dm-tree in ./.local/lib/python3.11/site-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: psutil in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (5.9.0)
# Requirement already satisfied: pyarrow in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (14.0.2)
# Requirement already satisfied: simple-parsing in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (1.15.0)
# Requirement already satisfied: toml in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.9.1 in ./.local/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.9.2)
# Requirement already satisfied: fsspec in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2024.3.1)
# Requirement already satisfied: importlib_resources in ./.local/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (6.4.3)
# Requirement already satisfied: zipp in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.15.1)
# Requirement already satisfied: docstring-parser~=0.15 in ./.local/lib/python3.11/site-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in ./.local/lib/python3.11/site-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.63.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in ./.local/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: absl-py in ./.local/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in ./.local/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in ./.local/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in ./.local/lib/python3.11/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in ./.local/lib/python3.11/site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
# !python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"
# Out:
# 2024-09-08 21:42:49.040326: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-08 21:42:49.063099: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-08 21:42:49.069537: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-08 21:42:49.086546: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-08 21:42:50.942090: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import keras
import keras_cv
from keras import layers, regularizers
import matplotlib.pyplot as plt
import os
from PIL import Image
import pandas as pd
from keras.callbacks import EarlyStopping
import math
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from time import time
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix, RocCurveDisplay, PrecisionRecallDisplay
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
# from torch.utils.data import DataLoader, Dataset

# %%
# !pwd
# !ls koa_scratch
# Out:
# /home/jctactay
# images

# %% [markdown]
# ## Data preprocessing

# %%
# load/reconcile labels
cols = ["species","image","distinctiveness","quality"]
labels1 = pd.read_csv('pifsc_labels_detail.csv')[cols]
labels1[['quality', 'distinctiveness']] = labels1[['distinctiveness', 'quality']]

cols = ["species","filename","distinctiveness","quality"]
labels2 = pd.read_csv('pifsc_labels2.csv')[cols]
labels2.columns = ["species","image","distinctiveness","quality"]

labels = pd.concat([labels1, labels2]).reset_index(drop=True)

# %%
is_na = labels.quality.isna()
labels = labels.loc[~is_na]
labels = labels.drop_duplicates(subset='image', keep='first')
print(len(labels.image))
# Out:
# 3586

# %%
# remove low-quality images
labels = labels.drop(labels[labels.quality == 3].index)
print(len(labels.image))
# Out:
# 2595

# %%
paths = []
for index, row in labels.iterrows():
    paths.append("/home/jctactay/koa_scratch/images/" + row.image)
assert len(labels) == len(paths)

# %%
# image reading/processing
def load_img(path):
    img = Image.open(path)
    img = img.resize((256,256))
    np_img = np.array(img)/127.5 - 1
    return os.path.basename(path), np_img
def load_images_into_dict():
    imgs = {}

    num_workers = 8
    
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        future_to_img = {executor.submit(load_img, path): path for path in paths}

        for future in as_completed(future_to_img):
            img_name, img = future.result()
            imgs[img_name] = img

    return imgs
    
t0 = time()

imgs = load_images_into_dict()
print(f"Done in {time() - t0: .3f}s")
# Out:
# Done in  138.326s

# %%
value_counts = labels.quality.value_counts()
value_counts.index = pd.to_numeric(value_counts.index)
value_counts = value_counts.sort_index()
value_counts
# Out:
# quality
# 1    1116
# 2    1479
# Name: count, dtype: int64

# %%
print(labels)
# Out:
#                  species                           image  distinctiveness  \
# 1        spinner_dolphin              007097146016e6.jpg              2.0
# 2        spinner_dolphin              009a307f9f483c.jpg              2.0
# 3        spinner_dolphin              00eea1a5b9d8bc.jpg              2.0
# 4        spinner_dolphin              01287e826d29a8.jpg              2.0
# 5        spinner_dolphin              014677910446f1.jpg              2.0
# ...                  ...                             ...              ...
# 3395  melon_headed_whale  PIFSC_20110503-S3_C-4871ed.jpg              2.0
# 3396  melon_headed_whale  PIFSC_20110503-S3_C-5019ed.jpg              2.0
# 3397  melon_headed_whale  PIFSC_20110503-S3_C-5172c-.jpg              2.0
# 3398  melon_headed_whale  PIFSC_20110503-S3_Z-3943ed.jpg              2.0
# 3399  melon_headed_whale     SIO_20090605-S12_0784ed.jpg              2.0
#
#       quality
# 1           2
# 2           1
# 3           1
# 4           1
# 5           2
# ...       ...
# 3395        1
# 3396        2
# 3397        2
# 3398        2
# 3399        2
#
# [2595 rows x 4 columns]

# %%
assert len(imgs) == len(labels)

# %%
# readjust labels to range of [0,1]
Y = labels.quality
if min(np.unique(Y)) != 0:
    for i in range(len(Y)):
        Y.iat[i] -= 1
print(np.unique(Y))
X = np.array([imgs[i] for i in labels.image])
print(len(Y))
print(len(X))
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25, stratify=Y_train, random_state=42)
# Out:
# [0 1]
# 2595
# 2595

# %%
print(len(X_train), len(X_val), len(X_test))
# Out:
# 1557 519 519

# %%
# weights per sample instead of per class
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(Y_train), y=Y_train)
print(class_weights)
class_weights_dict = dict(zip(np.unique(Y_train), class_weights))
sample_weights = np.array([class_weights_dict[label] for label in Y_train])
sample_weights
# Out:
# [1.1619403  0.87767756]
# array([1.1619403 , 0.87767756, 0.87767756, ..., 0.87767756, 1.1619403 ,
#        1.1619403 ])

# %%
def augment_image(image, label, weight):
    image = augmentation_layers(image)
    if tf.math.reduce_any(tf.equal(label, 2)):
        image = poor_augmentation_layers(image)
    return image, label, weight

# %%
augmentation_layers = keras.Sequential([
    keras.layers.RandomFlip(mode="horizontal", seed=42),
    keras.layers.RandomTranslation(height_factor=0.2, width_factor=0.2, seed=42)
])

poor_augmentation_layers = keras.Sequential([
    keras.layers.RandomRotation(factor=0.1, seed=42),
    keras_cv.layers.RandomSharpness(factor=0.2, value_range=[0,1], seed=42),
    keras_cv.layers.RandomSaturation(factor=(0.0, 0.5), seed=42)
])
# Out:
# 2024-09-08 21:45:19.878673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:07:00.0, compute capability: 7.0

# %%
t0 = time()
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train, sample_weights))
# controls augmentation
# train_dataset = train_dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
print("Done in %0.3fs" % (time() - t0))
# Out:
# Done in 5.254s

# %% [markdown]
# ## Visualize augmentations

# %%
# Inspect the structure of the dataset
for batch in train_dataset.take(1):
    print("Batch structure:")
    for element in batch:
        print(f"Element shape: {element.shape}")
        print(f"Element type: {type(element)}")

# %%
def visualize_augmentation(dataset, num_images=15):
    for batch in dataset.take(1):  # Take one batch
        images, _, _ = batch
        plt.figure(figsize=(15, 15))
        for i in range(min(num_images, images.shape[0])):
            plt.subplot(3, 5, i + 1)
            image = images[i].numpy()
            image = (image + 1) / 2
            plt.imshow(image)
        plt.show()

# Visualize augmented images
visualize_augmentation(train_dataset)

# %% [markdown]
# ## Model

# %%
# load pretrained model
base_model = keras.applications.Xception(
    weights='imagenet',
    input_shape=(256,256,3),
    include_top=False)
# freeze base model
base_model.trainable = False

# %%
base_model.summary(show_trainable=True)
# Out:
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer       │ (None, 256,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 256, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 127,     │       864 │ input_layer[0… │   N   │
# │ (Conv2D)          │ 127, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 127,     │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 127, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 127,     │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 127, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 125,     │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 125, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 125,     │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 125, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 125,     │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 125, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 125,     │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 125, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 125,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 125, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 125,     │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 125, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 125,     │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 125, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 125,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 125, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d (Conv2D)   │ (None, 63, 63,  │     8,192 │ block1_conv2_… │   N   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 63, 63,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 63, 63,  │       512 │ conv2d[0][0]   │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add (Add)         │ (None, 63, 63,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 63, 63,  │         0 │ add[0][0]      │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 63, 63,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 63, 63,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 63, 63,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 63, 63,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 63, 63,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 32, 32,  │    32,768 │ add[0][0]      │   N   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 32, 32,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 32, 32,  │     1,024 │ conv2d_1[0][0] │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 32, 32,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 32, 32,  │         0 │ add_1[0][0]    │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 32, 32,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 32, 32,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 32, 32,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 32, 32,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 32, 32,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 16, 16,  │   186,368 │ add_1[0][0]    │   N   │
# │                   │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 16, 16,  │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 16, 16,  │     2,912 │ conv2d_2[0][0] │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 16, 16,  │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 16, 16,  │         0 │ add_2[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 16, 16,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 16, 16,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 16, 16,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 16, 16,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 16, 16,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 16, 16,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 16, 16,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 16, 16,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 16, 16,  │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_2[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 16, 16,  │         0 │ add_3[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 16, 16,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 16, 16,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 16, 16,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 16, 16,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 16, 16,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 16, 16,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 16, 16,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 16, 16,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 16, 16,  │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_3[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 16, 16,  │         0 │ add_4[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 16, 16,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 16, 16,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 16, 16,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 16, 16,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 16, 16,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 16, 16,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 16, 16,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 16, 16,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_5 (Add)       │ (None, 16, 16,  │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_4[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 16, 16,  │         0 │ add_5[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 16, 16,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 16, 16,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 16, 16,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 16, 16,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 16, 16,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 16, 16,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 16, 16,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 16, 16,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_6 (Add)       │ (None, 16, 16,  │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_5[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 16, 16,  │         0 │ add_6[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 16, 16,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 16, 16,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 16, 16,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 16, 16,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 16, 16,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 16, 16,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 16, 16,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 16, 16,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_7 (Add)       │ (None, 16, 16,  │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_6[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 16, 16,  │         0 │ add_7[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 16, 16,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 16, 16,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 16, 16,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 16, 16,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 16, 16,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 16, 16,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 16, 16,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 16, 16,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_8 (Add)       │ (None, 16, 16,  │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_7[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 16, 16,  │         0 │ add_8[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 16, 16,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 16, 16,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 16, 16,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 16, 16,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 16, 16,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 16, 16,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 16, 16,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 16, 16,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_9 (Add)       │ (None, 16, 16,  │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_8[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 16, 16,  │         0 │ add_9[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 16, 16,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 16, 16,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 16, 16,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 16, 16,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 16, 16,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 16, 16,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 16, 16,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 16, 16,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_10 (Add)      │ (None, 16, 16,  │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_9[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 16, 16,  │         0 │ add_10[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 16, 16,  │   536,536 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 16, 16,  │     2,912 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 16, 16,  │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 16, 16,  │   752,024 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 16, 16,  │     4,096 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 8, 8,    │   745,472 │ add_10[0][0]   │   N   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 8, 8,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 8, 8,    │     4,096 │ conv2d_3[0][0] │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_11 (Add)      │ (None, 8, 8,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 8, 8,    │ 1,582,080 │ add_11[0][0]   │   N   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 8, 8,    │     6,144 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 8, 8,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 8, 8,    │ 3,159,552 │ block14_sepco… │   N   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 8, 8,    │     8,192 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 8, 8,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# modify input layer
inputs = keras.Input(shape=(256,256,3))
# x = augmentation_layers(inputs)
# inference mode so weights do not update)
x = base_model(inputs, training=False)
# new trainable layers
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.4)(x)
# x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.1))(x)
# x = keras.layers.Dropout(0.3)(x)
outputs = keras.layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs, outputs)
model.summary(show_trainable=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_1 (InputLayer)  │ (None, 256, 256, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ xception (Functional)       │ (None, 8, 8, 2048)    │ 20,861,480 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 2048)          │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 1024)          │  2,098,176 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 1)             │      1,025 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 22,960,681 (87.59 MB)
#  Trainable params: 2,099,201 (8.01 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %% [markdown]
# ## Helper functions

# %%
def plot_history(history):
    num_subplots = len(history.history.keys())//2
    fig, ax = plt.subplots(num_subplots)
    for i, metric in enumerate(history.history.keys()):
        ax[i%num_subplots].plot(history.history[metric], label=metric)
        ax[i%num_subplots].legend()

# %%
def predict(dataset, pred_model):
    true = []
    preds = []
    for images, labels in dataset:
        pred_soft = pred_model.predict(images)
        pred = np.round(pred_soft)
        true.extend(labels.numpy())
        preds.extend(pred)
    return true, preds

# %% [markdown]
# ## Initial fit

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss")

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss='binary_crossentropy',
              metrics=['accuracy'])
# history = model.fit(X_train, Y_train, epochs=15, validation_data=(X_val, Y_val), sample_weight=sample_weights, callbacks=callback)
history = model.fit(train_dataset, epochs=15, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725832047.128019  996122 service.cc:146] XLA service 0x14a280018190 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725832047.128062  996122 service.cc:154]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2024-09-08 21:47:27.287853: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-08 21:47:28.354711: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1725832050.645515  996122 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1725832050.825217  996122 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.6172 - loss: 14.2412
# I0000 00:00:1725832053.760400  996122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5674 - loss: 8.8898
# E0000 00:00:1725832059.467042  996122 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1725832059.637081  996122 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 329ms/step - accuracy: 0.5678 - loss: 8.7513 - val_accuracy: 0.6724 - val_loss: 1.5779
# Epoch 2/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.6374 - loss: 1.3480 - val_accuracy: 0.6513 - val_loss: 0.9206
# Epoch 3/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6439 - loss: 0.9013 - val_accuracy: 0.6802 - val_loss: 0.7725
# Epoch 4/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.6309 - loss: 0.7897 - val_accuracy: 0.6782 - val_loss: 0.7109
# Epoch 5/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.6133 - loss: 0.7404 - val_accuracy: 0.6166 - val_loss: 0.6940
# Epoch 6/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6250 - loss: 0.7115 - val_accuracy: 0.6224 - val_loss: 0.7016
# Epoch 7/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.6145 - loss: 0.6974 - val_accuracy: 0.6609 - val_loss: 0.6787
# Epoch 8/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6173 - loss: 0.6836 - val_accuracy: 0.6108 - val_loss: 0.6894
# Epoch 9/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.6180 - loss: 0.6795 - val_accuracy: 0.6609 - val_loss: 0.6708
# Epoch 10/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.6328 - loss: 0.6760 - val_accuracy: 0.6532 - val_loss: 0.6701
# Epoch 11/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.6169 - loss: 0.6717 - val_accuracy: 0.6301 - val_loss: 0.6715
# Epoch 12/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.6057 - loss: 0.6785 - val_accuracy: 0.6435 - val_loss: 0.6688
# Epoch 13/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6185 - loss: 0.6760 - val_accuracy: 0.6609 - val_loss: 0.6644
# Epoch 14/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.6331 - loss: 0.6719 - val_accuracy: 0.6474 - val_loss: 0.6674
# Epoch 15/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.6304 - loss: 0.6718 - val_accuracy: 0.6570 - val_loss: 0.6673

# %%
plot_history(history)

# %%
results = model.evaluate(test_dataset)
print("test loss, test acc:", results)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6278 - loss: 0.6576
# test loss, test acc: [0.658065676689148, 0.6454720497131348]

# %%
true, pred = predict(test_dataset, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 2024-09-08 21:49:25.563353: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(classification_report(true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.66      0.62       223
#            1       0.71      0.63      0.67       296
#
#     accuracy                           0.65       519
#    macro avg       0.64      0.65      0.64       519
# weighted avg       0.65      0.65      0.65       519

# %%
cm = confusion_matrix(true, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %% [markdown]
# ## Top 4 layers

# %%
# unfreeze top 4 base layers
for layer in base_model.layers[-4:]:
    layer.trainable = True
model.summary(show_trainable=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_1 (InputLayer)  │ (None, 256, 256, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ xception (Functional)       │ (None, 8, 8, 2048)    │ 20,861,480 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 2048)          │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 1024)          │  2,098,176 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 1)             │      1,025 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 27,159,085 (103.60 MB)
#  Trainable params: 5,262,849 (20.08 MB)
#  Non-trainable params: 17,697,832 (67.51 MB)
#  Optimizer params: 4,198,404 (16.02 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss", start_from_epoch=5)

# %%
# top 4 layers unfrozen
model.compile(optimizer=keras.optimizers.Adam(1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=20
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.6754 - loss: 0.6607 - val_accuracy: 0.6686 - val_loss: 0.6633
# Epoch 2/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.6727 - loss: 0.6509 - val_accuracy: 0.6724 - val_loss: 0.6610
# Epoch 3/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6695 - loss: 0.6512 - val_accuracy: 0.6705 - val_loss: 0.6585
# Epoch 4/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6603 - loss: 0.6438 - val_accuracy: 0.6686 - val_loss: 0.6551
# Epoch 5/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.6774 - loss: 0.6406 - val_accuracy: 0.6705 - val_loss: 0.6523
# Epoch 6/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6815 - loss: 0.6396 - val_accuracy: 0.6763 - val_loss: 0.6498
# Epoch 7/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.6631 - loss: 0.6331 - val_accuracy: 0.6782 - val_loss: 0.6475
# Epoch 8/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.6827 - loss: 0.6285 - val_accuracy: 0.6782 - val_loss: 0.6457
# Epoch 9/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.6752 - loss: 0.6290 - val_accuracy: 0.6840 - val_loss: 0.6439
# Epoch 10/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.6810 - loss: 0.6258 - val_accuracy: 0.6802 - val_loss: 0.6421
# Epoch 11/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.6875 - loss: 0.6221 - val_accuracy: 0.6821 - val_loss: 0.6408
# Epoch 12/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.6866 - loss: 0.6238 - val_accuracy: 0.6840 - val_loss: 0.6394
# Epoch 13/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.6819 - loss: 0.6204 - val_accuracy: 0.6840 - val_loss: 0.6380
# Epoch 14/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.6879 - loss: 0.6161 - val_accuracy: 0.6840 - val_loss: 0.6368
# Epoch 15/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.6934 - loss: 0.6139 - val_accuracy: 0.6859 - val_loss: 0.6361
# Epoch 16/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.6928 - loss: 0.6088 - val_accuracy: 0.6840 - val_loss: 0.6353
# Epoch 17/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.6957 - loss: 0.6111 - val_accuracy: 0.6840 - val_loss: 0.6347
# Epoch 18/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.6827 - loss: 0.6101 - val_accuracy: 0.6859 - val_loss: 0.6336
# Epoch 19/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.7020 - loss: 0.6030 - val_accuracy: 0.6859 - val_loss: 0.6326
# Epoch 20/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.7029 - loss: 0.6069 - val_accuracy: 0.6859 - val_loss: 0.6317

# %%
plot_history(history)

# %%
true, pred = predict(test_dataset, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 2024-09-08 21:52:49.398253: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(classification_report(true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       223
#            1       0.72      0.71      0.71       296
#
#     accuracy                           0.68       519
#    macro avg       0.67      0.67      0.67       519
# weighted avg       0.68      0.68      0.68       519

# %%
cm = confusion_matrix(true, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %%
# model.save("4-layers-big-binary.keras")

# %% [markdown]
# ## Top 8 layers

# %%
# unfreeze top 8 base layers
for layer in base_model.layers[-8:]:
    layer.trainable = True
model.summary(show_trainable=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_1 (InputLayer)  │ (None, 256, 256, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ xception (Functional)       │ (None, 8, 8, 2048)    │ 20,861,480 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 2048)          │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 1024)          │  2,098,176 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 1)             │      1,025 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 33,486,381 (127.74 MB)
#  Trainable params: 6,850,049 (26.13 MB)
#  Non-trainable params: 16,110,632 (61.46 MB)
#  Optimizer params: 10,525,700 (40.15 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss", start_from_epoch=10)

# %%
# top 8 layers unfrozen
model.compile(optimizer=keras.optimizers.Adam(1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=40
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 261ms/step - accuracy: 0.7082 - loss: 0.6497 - val_accuracy: 0.6917 - val_loss: 0.6267
# Epoch 2/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.7270 - loss: 0.6347 - val_accuracy: 0.6802 - val_loss: 0.6219
# Epoch 3/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.7173 - loss: 0.6296 - val_accuracy: 0.6840 - val_loss: 0.6177
# Epoch 4/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.7177 - loss: 0.6195 - val_accuracy: 0.6975 - val_loss: 0.6115
# Epoch 5/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.7330 - loss: 0.6085 - val_accuracy: 0.7168 - val_loss: 0.6063
# Epoch 6/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.7314 - loss: 0.6010 - val_accuracy: 0.7225 - val_loss: 0.6036
# Epoch 7/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.7398 - loss: 0.5882 - val_accuracy: 0.7110 - val_loss: 0.6027
# Epoch 8/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.7456 - loss: 0.5802 - val_accuracy: 0.7110 - val_loss: 0.6030
# Epoch 9/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.7527 - loss: 0.5694 - val_accuracy: 0.7110 - val_loss: 0.6028
# Epoch 10/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.7568 - loss: 0.5628 - val_accuracy: 0.7129 - val_loss: 0.6033
# Epoch 11/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.7561 - loss: 0.5562 - val_accuracy: 0.7052 - val_loss: 0.6029
# Epoch 12/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.7554 - loss: 0.5461 - val_accuracy: 0.7110 - val_loss: 0.6020
# Epoch 13/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.7723 - loss: 0.5374 - val_accuracy: 0.7168 - val_loss: 0.6009
# Epoch 14/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.7797 - loss: 0.5305 - val_accuracy: 0.7168 - val_loss: 0.5998
# Epoch 15/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.7841 - loss: 0.5214 - val_accuracy: 0.7187 - val_loss: 0.5989
# Epoch 16/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.7804 - loss: 0.5118 - val_accuracy: 0.7225 - val_loss: 0.5968
# Epoch 17/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.7881 - loss: 0.5103 - val_accuracy: 0.7187 - val_loss: 0.5965
# Epoch 18/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.7942 - loss: 0.4971 - val_accuracy: 0.7206 - val_loss: 0.5962
# Epoch 19/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.8070 - loss: 0.4913 - val_accuracy: 0.7206 - val_loss: 0.5963
# Epoch 20/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8061 - loss: 0.4826 - val_accuracy: 0.7225 - val_loss: 0.5955
# Epoch 21/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.8132 - loss: 0.4733 - val_accuracy: 0.7225 - val_loss: 0.5957
# Epoch 22/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8138 - loss: 0.4645 - val_accuracy: 0.7225 - val_loss: 0.5961
# Epoch 23/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.8272 - loss: 0.4592 - val_accuracy: 0.7225 - val_loss: 0.5971
# Epoch 24/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8376 - loss: 0.4428 - val_accuracy: 0.7264 - val_loss: 0.5975
# Epoch 25/40
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.8444 - loss: 0.4366 - val_accuracy: 0.7225 - val_loss: 0.5996

# %%
plot_history(history)

# %%
true, pred = predict(test_dataset, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
print(classification_report(true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.64      0.65       223
#            1       0.74      0.77      0.75       296
#
#     accuracy                           0.71       519
#    macro avg       0.70      0.70      0.70       519
# weighted avg       0.71      0.71      0.71       519

# %%
cm = confusion_matrix(true, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %%
# model.save("8-layers-big-binary.keras")

# %% [markdown]
# ## Top 10 layers

# %%
for layer in base_model.layers[-10:]:
    layer.trainable = True
model.summary(show_trainable=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_1 (InputLayer)  │ (None, 256, 256, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ xception (Functional)       │ (None, 8, 8, 2048)    │ 20,861,480 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 2048)          │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 1024)          │  2,098,176 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 1)             │      1,025 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 36,660,781 (139.85 MB)
#  Trainable params: 7,595,521 (28.97 MB)
#  Non-trainable params: 15,365,160 (58.61 MB)
#  Optimizer params: 13,700,100 (52.26 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss", start_from_epoch=15)

# %%
# top 10 layers unfrozen
model.compile(optimizer=keras.optimizers.Adam(5e-6),
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=60
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 26s 304ms/step - accuracy: 0.8207 - loss: 0.4751 - val_accuracy: 0.7206 - val_loss: 0.5994
# Epoch 2/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.8243 - loss: 0.4628 - val_accuracy: 0.7187 - val_loss: 0.5973
# Epoch 3/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8200 - loss: 0.4629 - val_accuracy: 0.7225 - val_loss: 0.5963
# Epoch 4/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.8218 - loss: 0.4573 - val_accuracy: 0.7206 - val_loss: 0.5975
# Epoch 5/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8315 - loss: 0.4510 - val_accuracy: 0.7168 - val_loss: 0.5985
# Epoch 6/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8324 - loss: 0.4456 - val_accuracy: 0.7110 - val_loss: 0.5991
# Epoch 7/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8468 - loss: 0.4384 - val_accuracy: 0.7225 - val_loss: 0.5985
# Epoch 8/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8502 - loss: 0.4337 - val_accuracy: 0.7264 - val_loss: 0.5980
# Epoch 9/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.8458 - loss: 0.4300 - val_accuracy: 0.7264 - val_loss: 0.5997
# Epoch 10/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8492 - loss: 0.4199 - val_accuracy: 0.7264 - val_loss: 0.6003
# Epoch 11/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.8565 - loss: 0.4205 - val_accuracy: 0.7187 - val_loss: 0.6000
# Epoch 12/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8633 - loss: 0.4130 - val_accuracy: 0.7168 - val_loss: 0.6004
# Epoch 13/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.8698 - loss: 0.4048 - val_accuracy: 0.7168 - val_loss: 0.6017
# Epoch 14/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8688 - loss: 0.3945 - val_accuracy: 0.7168 - val_loss: 0.6034
# Epoch 15/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8642 - loss: 0.3987 - val_accuracy: 0.7148 - val_loss: 0.6037
# Epoch 16/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8750 - loss: 0.3872 - val_accuracy: 0.7187 - val_loss: 0.6057
# Epoch 17/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8802 - loss: 0.3872 - val_accuracy: 0.7129 - val_loss: 0.6069
# Epoch 18/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.8790 - loss: 0.3798 - val_accuracy: 0.7206 - val_loss: 0.6099
# Epoch 19/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8943 - loss: 0.3722 - val_accuracy: 0.7129 - val_loss: 0.6105
# Epoch 20/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8863 - loss: 0.3688 - val_accuracy: 0.7148 - val_loss: 0.6116
# Epoch 21/60
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8910 - loss: 0.3622 - val_accuracy: 0.7148 - val_loss: 0.6132

# %%
plot_history(history)

# %%
true, pred = predict(test_dataset, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 2024-09-08 21:59:32.757025: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(classification_report(true, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.64       223
#            1       0.72      0.77      0.74       296
#
#     accuracy                           0.70       519
#    macro avg       0.69      0.69      0.69       519
# weighted avg       0.70      0.70      0.70       519

# %%
cm = confusion_matrix(true, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %%
# model.save("10-layers-big-binary.keras")

# %% [markdown]
# This model is better at predicting medium quality, while multiclass is better at predicting high quality; both models are underperforming either way

# %% [markdown]
# ## ROC and Precision-Recall curves

# %%
disp = RocCurveDisplay.from_predictions(true, pred, name="binary", plot_chance_level=True)
# plt.plot([0, 1], [0, 1], color='k', linestyle='--')

# %%
disp = PrecisionRecallDisplay.from_predictions(true, pred, name="binary", plot_chance_level=True)
