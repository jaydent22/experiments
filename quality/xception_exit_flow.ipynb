# %% [markdown]
# # ImageNet Fine Tuning Exit Flow
# This experiment will involve fine-tuning the pretrained Xception model. It will explore retraining the top layer and exit flow of the model.

# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Fri Sep 27 23:51:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-32GB           On  |   00000000:B2:00.0 Off |                    0 |
# | N/A   30C    P0             40W /  300W |       1MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install --upgrade pip

# %%
# !pip install tensorflow[and-cuda]

# %%
# !pip install --upgrade keras-cv tensorflow
# !pip install --upgrade keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-cv in ./.local/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: tensorflow in ./.local/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: packaging in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras-cv) (23.2)
# Requirement already satisfied: absl-py in ./.local/lib/python3.11/site-packages (from keras-cv) (2.1.0)
# Requirement already satisfied: regex in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras-cv) (2023.10.3)
# Requirement already satisfied: tensorflow-datasets in ./.local/lib/python3.11/site-packages (from keras-cv) (4.9.6)
# Requirement already satisfied: keras-core in ./.local/lib/python3.11/site-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in ./.local/lib/python3.11/site-packages (from keras-cv) (0.2.9)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.local/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.11/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.11/site-packages (from tensorflow) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.local/lib/python3.11/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in ./.local/lib/python3.11/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in ./.local/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (2.2.3)
# Requirement already satisfied: tqdm in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from kagglehub->keras-cv) (4.65.0)
# Requirement already satisfied: dm-tree in ./.local/lib/python3.11/site-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: psutil in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (5.9.0)
# Requirement already satisfied: pyarrow in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (14.0.2)
# Requirement already satisfied: simple-parsing in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (1.15.0)
# Requirement already satisfied: toml in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in ./.local/lib/python3.11/site-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.9.1 in ./.local/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.9.2)
# Requirement already satisfied: fsspec in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2024.3.1)
# Requirement already satisfied: importlib_resources in ./.local/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (6.4.3)
# Requirement already satisfied: zipp in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from etils[enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.15.1)
# Requirement already satisfied: docstring-parser~=0.15 in ./.local/lib/python3.11/site-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in ./.local/lib/python3.11/site-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.63.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in ./.local/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: absl-py in ./.local/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in ./.local/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in ./.local/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in ./.local/lib/python3.11/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in ./.local/lib/python3.11/site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/apps/software/lang/Anaconda3/2024.02-1/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
# !python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"
# Out:
# 2024-09-27 23:51:31.224609: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-27 23:51:31.240360: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-27 23:51:31.256378: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-27 23:51:31.261142: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-27 23:51:31.273536: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-27 23:51:32.524392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import keras
# import keras_cv
from keras import layers, regularizers
import matplotlib.pyplot as plt
import os
from PIL import Image
import pandas as pd
from keras.callbacks import EarlyStopping
import math
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from time import time
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
from concurrent.futures import ThreadPoolExecutor, as_completed
import tensorflow as tf
# from torch.utils.data import DataLoader, Dataset

# %%
# !pwd
# !ls koa_scratch
# Out:
# /home/jctactay
# images

# %% [markdown]
# ## Data preprocessing

# %%
# image reading/processing
def load_img(path):
    img = Image.open(path)
    img = img.resize((128,128))
    np_img = np.array(img)/127.5 - 1
    return os.path.basename(path), np_img
def load_images_into_dict(img_dir):
    imgs = {}
    paths = [os.path.join(img_dir, img) for img in os.listdir(img_dir)]

    num_workers = 8
    
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        future_to_img = {executor.submit(load_img, path): path for path in paths}

        for future in as_completed(future_to_img):
            img_name, img = future.result()
            imgs[img_name] = img

    return imgs
    
t0 = time()
home = "/home/jctactay/koa_scratch/images"

imgs = load_images_into_dict(home)
print(f"Done in {time() - t0: .3f}s")
# Out:
# Done in  155.781s

# %%
# load/reconcile labels
cols = ["species","image","distinctiveness","quality"]
labels1 = pd.read_csv('pifsc_labels_detail.csv')[cols]
labels1[['quality', 'distinctiveness']] = labels1[['distinctiveness', 'quality']]

cols = ["species","filename","distinctiveness","quality"]
labels2 = pd.read_csv('pifsc_labels2.csv')[cols]
labels2.columns = ["species","image","distinctiveness","quality"]

labels = pd.concat([labels1, labels2]).reset_index(drop=True)

# %%
print(len(imgs))
# Out:
# 3613

# %%
is_na = labels.quality.isna()
labels = labels.loc[~is_na]
labels = labels.drop_duplicates(subset='image', keep='first')

img_names = labels.image.tolist()
features = {k: v for k, v in imgs.items() if k in img_names}
assert len(features) == len(labels)

# %%
labels.quality.value_counts()
# Out:
# quality
# 2    1479
# 1    1116
# 3     991
# Name: count, dtype: int64

# %%
# check for nans
for k, v in zip(features.keys(), features.values()):
    if np.isnan(v.any()):
        print(k)

# %%
print(labels)
# Out:
#                  species                           image  distinctiveness  \
# 0        spinner_dolphin              0011f7a65044e4.jpg              2.0
# 1        spinner_dolphin              007097146016e6.jpg              2.0
# 2        spinner_dolphin              009a307f9f483c.jpg              2.0
# 3        spinner_dolphin              00eea1a5b9d8bc.jpg              2.0
# 4        spinner_dolphin              01287e826d29a8.jpg              2.0
# ...                  ...                             ...              ...
# 3587  melon_headed_whale  PIFSC_20110503-S3_C-5088a-.jpg              2.0
# 3588  melon_headed_whale  PIFSC_20110503-S3_Z-3913a-.jpg              1.0
# 3589  melon_headed_whale  PIFSC_20110503-S3_Z-3914ed.jpg              NaN
# 3590  melon_headed_whale  PIFSC_20110503-S3_C-4846a-.jpg              1.0
# 3591  melon_headed_whale  PIFSC_20110503-S3_Z-3866ed.jpg              1.0
#
#       quality
# 0           3
# 1           2
# 2           1
# 3           1
# 4           1
# ...       ...
# 3587        3
# 3588        3
# 3589        3
# 3590        3
# 3591        3
#
# [3586 rows x 4 columns]

# %%
Y = labels.quality
# print
if min(np.unique(Y)) != 0:
    for i in range(len(Y)):
        Y.iat[i] -= 1
print(np.unique(Y))
X = np.array([features[i] for i in labels.image])
print(len(Y))
print(len(X))
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25, stratify=Y_train, random_state=42)
# Out:
# [0 1 2]
# 3586
# 3586

# %%
print(len(X_train), len(X_val), len(X_test))
# Out:
# 2151 717 718

# %%
# weights per sample instead of per class
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(Y_train), y=Y_train)
print(class_weights)
class_weights_dict = dict(zip(np.unique(Y_train), class_weights))
sample_weights = np.array([class_weights_dict[label] for label in Y_train])
sample_weights
# Out:
# [1.07174888 0.80834273 1.20504202]
# array([1.20504202, 1.07174888, 0.80834273, ..., 0.80834273, 1.20504202,
#        1.20504202])

# %%
augmentation_layers = keras.Sequential([
    keras.layers.RandomFlip(mode="horizontal", seed=42),
    keras.layers.RandomTranslation(height_factor=0.2, width_factor=0.2, seed=42)
])

poor_augmentation_layers = keras.Sequential([
    keras.layers.RandomRotation(factor=0.1, seed=42),
    # keras_cv.layers.RandomSharpness(factor=0.2, value_range=[0,1], seed=42),
    keras.layers.RandomFlip(mode="vertical", seed=42),
    # keras_cv.layers.RandomSaturation(factor=(0.0, 0.5), seed=42)
])
# Out:
# 2024-09-27 23:54:14.447860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:b2:00.0, compute capability: 7.0

# %%
def augment_image(image, label, weight):
    image = augmentation_layers(image)
    if tf.math.reduce_any(tf.equal(label, 2)):
        image = poor_augmentation_layers(image)
    return image, label, weight

# %%
t0 = time()
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train, sample_weights))
# controls augmentation
train_dataset = train_dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
print("Done in %0.3fs" % (time() - t0))
# Out:
# Done in 1.998s

# %% [markdown]
# ## Visualize augmentations

# %%
# Inspect the structure of the dataset
for batch in train_dataset.take(1):
    print("Batch structure:")
    for element in batch:
        print(f"Element shape: {element.shape}")
        print(f"Element type: {type(element)}")
# Out:
# Batch structure:
# Element shape: (32, 128, 128, 3)
# Element type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Element shape: (32,)
# Element type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Element shape: (32,)
# Element type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 2024-09-27 23:54:17.210657: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def visualize_batch_augmentation(dataset, num_images=15):
    for batch in dataset.take(1):  # Take one batch
        images, _, _ = batch
        plt.figure(figsize=(15, 15))
        for i in range(min(num_images, images.shape[0])):
            plt.subplot(3, 5, i + 1)
            image = images[i].numpy()
            image = (image + 1) / 2
            plt.imshow(image)
        plt.show()

# Visualize augmented images
visualize_batch_augmentation(train_dataset)
# Out:
# 2024-09-27 23:54:18.982860: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Model

# %%
# load pretrained model
base_model = keras.applications.Xception(
    weights='imagenet',
    input_shape=(128,128,3),
    include_top=False)
# freeze base model
base_model.trainable = False

# %%
base_model.summary(show_trainable=True)
# Out:
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_2     │ (None, 128,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 128, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 63, 63,  │       864 │ input_layer_2… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 63, 63,  │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 63, 63,  │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 61, 61,  │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 61, 61,  │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 61, 61,  │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 61, 61,  │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 61, 61,  │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d (Conv2D)   │ (None, 31, 31,  │     8,192 │ block1_conv2_… │   N   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 31, 31,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 31, 31,  │       512 │ conv2d[0][0]   │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add (Add)         │ (None, 31, 31,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │         0 │ add[0][0]      │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 31, 31,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 31, 31,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 16, 16,  │    32,768 │ add[0][0]      │   N   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 16, 16,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 16, 16,  │     1,024 │ conv2d_1[0][0] │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 16, 16,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │         0 │ add_1[0][0]    │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 16, 16,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 16, 16,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 8, 8,    │   186,368 │ add_1[0][0]    │   N   │
# │                   │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 8, 8,    │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 8, 8,    │     2,912 │ conv2d_2[0][0] │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 8, 8,    │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │         0 │ add_2[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_2[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │         0 │ add_3[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_3[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │         0 │ add_4[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_5 (Add)       │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_4[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │         0 │ add_5[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_6 (Add)       │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_5[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │         0 │ add_6[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_7 (Add)       │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_6[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │         0 │ add_7[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_8 (Add)       │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_7[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │         0 │ add_8[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_9 (Add)       │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_8[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │         0 │ add_9[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_10 (Add)      │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_9[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │         0 │ add_10[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 8, 8,    │   536,536 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │     2,912 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 8, 8,    │   752,024 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │     4,096 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 4, 4,    │   745,472 │ add_10[0][0]   │   N   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 4, 4,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 4, 4,    │     4,096 │ conv2d_3[0][0] │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_11 (Add)      │ (None, 4, 4,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 4, 4,    │ 1,582,080 │ add_11[0][0]   │   N   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │     6,144 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 4, 4,    │ 3,159,552 │ block14_sepco… │   N   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │     8,192 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# modify input layer
inputs = keras.Input(shape=(128,128,3))
# x = augmentation_layers(inputs)
# inference mode so weights do not update)
x = base_model(inputs, training=False)
# new trainable layers
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = keras.layers.Dropout(0.4)(x)
# x = keras.layers.Dense(512, activation='relu')(x)
# x = keras.layers.Dropout(0.3)(x)
outputs = keras.layers.Dense(3, activation='softmax')(x)
model = keras.Model(inputs, outputs)
model.summary(show_trainable=True)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_3 (InputLayer)  │ (None, 128, 128, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ xception (Functional)       │ (None, 4, 4, 2048)    │ 20,861,480 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 2048)          │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 1024)          │  2,098,176 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout (Dropout)           │ (None, 1024)          │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 3)             │      3,075 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 22,962,731 (87.60 MB)
#  Trainable params: 2,101,251 (8.02 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss")

# %%
def plot_history(history):
    num_subplots = len(history.history.keys())//2
    fig, ax = plt.subplots(num_subplots)
    for i, metric in enumerate(history.history.keys()):
        ax[i%num_subplots].plot(history.history[metric], label=metric)
        ax[i%num_subplots].legend()

# %% [markdown]
# ## Initial fit

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(train_dataset, epochs=30, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727481264.831710   76296 service.cc:146] XLA service 0x145a4400a1a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727481264.831748   76296 service.cc:154]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2024-09-27 23:54:24.996679: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-27 23:54:25.727800: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8902
#  5/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.3457 - loss: 15.4481
# I0000 00:00:1727481269.865239   76296 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 23s 216ms/step - accuracy: 0.4817 - loss: 10.1062 - val_accuracy: 0.4505 - val_loss: 3.5598
# Epoch 2/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.5929 - loss: 2.6671 - val_accuracy: 0.4784 - val_loss: 2.2343
# Epoch 3/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.5629 - loss: 1.7025 - val_accuracy: 0.4644 - val_loss: 1.7993
# Epoch 4/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.5768 - loss: 1.3063 - val_accuracy: 0.4784 - val_loss: 1.6380
# Epoch 5/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.5986 - loss: 1.1374 - val_accuracy: 0.4100 - val_loss: 1.5496
# Epoch 6/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.5847 - loss: 1.0177 - val_accuracy: 0.4393 - val_loss: 1.4742
# Epoch 7/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.5778 - loss: 1.0096 - val_accuracy: 0.4979 - val_loss: 1.2264
# Epoch 8/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.5938 - loss: 0.9325 - val_accuracy: 0.4672 - val_loss: 1.2337
# Epoch 9/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6066 - loss: 0.9029 - val_accuracy: 0.4840 - val_loss: 1.2563
# Epoch 10/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.6143 - loss: 0.8927 - val_accuracy: 0.4156 - val_loss: 1.2175
# Epoch 11/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5922 - loss: 0.8722 - val_accuracy: 0.4700 - val_loss: 1.1683
# Epoch 12/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.6067 - loss: 0.8523 - val_accuracy: 0.4616 - val_loss: 1.1740
# Epoch 13/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5810 - loss: 0.8649 - val_accuracy: 0.4798 - val_loss: 1.2269
# Epoch 14/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6098 - loss: 0.8785 - val_accuracy: 0.4589 - val_loss: 1.3273
# Epoch 15/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6152 - loss: 0.8493 - val_accuracy: 0.4895 - val_loss: 1.1333
# Epoch 16/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.6075 - loss: 0.8533 - val_accuracy: 0.4268 - val_loss: 1.1876
# Epoch 17/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.5955 - loss: 0.8367 - val_accuracy: 0.4700 - val_loss: 1.2034
# Epoch 18/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.5926 - loss: 0.8393 - val_accuracy: 0.5188 - val_loss: 1.1059
# Epoch 19/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.6084 - loss: 0.8587 - val_accuracy: 0.4770 - val_loss: 1.2258
# Epoch 20/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.6235 - loss: 0.8355 - val_accuracy: 0.4393 - val_loss: 1.2443
# Epoch 21/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5874 - loss: 0.8619 - val_accuracy: 0.4895 - val_loss: 1.1094
# Epoch 22/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6125 - loss: 0.8262 - val_accuracy: 0.5258 - val_loss: 1.0735
# Epoch 23/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.5829 - loss: 0.8429 - val_accuracy: 0.5021 - val_loss: 1.0956
# Epoch 24/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.5890 - loss: 0.8382 - val_accuracy: 0.4854 - val_loss: 1.1535
# Epoch 25/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.5834 - loss: 0.8692 - val_accuracy: 0.4575 - val_loss: 1.1046
# Epoch 26/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.5685 - loss: 0.8604 - val_accuracy: 0.5146 - val_loss: 1.0852
# Epoch 27/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.5988 - loss: 0.8472 - val_accuracy: 0.4868 - val_loss: 1.1575

# %%
plot_history(history)

# %%
pred_soft = model.predict(X_test)
preds = []
for i in pred_soft:
    preds.append(np.argmax(i))
print(classification_report(Y_test, preds))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.50       224
#            1       0.47      0.55      0.51       296
#            2       0.60      0.46      0.52       198
#
#     accuracy                           0.51       718
#    macro avg       0.53      0.50      0.51       718
# weighted avg       0.52      0.51      0.51       718

# %%
cm = confusion_matrix(Y_test, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %% [markdown]
# ## Exit flow

# %% [markdown]
# ### Block 14

# %%
print(base_model.layers[-7])
print(base_model.layers[-6])
# Out:
# <Add name=add_11, built=True>
# <SeparableConv2D name=block14_sepconv1, built=True>

# %%
# unfreeze last exit flow block (6 layers)
for layer in base_model.layers[-6:]:
    layer.trainable = True
base_model.summary(show_trainable=True)
# Out:
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_2     │ (None, 128,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 128, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 63, 63,  │       864 │ input_layer_2… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 63, 63,  │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 63, 63,  │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 61, 61,  │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 61, 61,  │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 61, 61,  │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 61, 61,  │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 61, 61,  │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d (Conv2D)   │ (None, 31, 31,  │     8,192 │ block1_conv2_… │   N   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 31, 31,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 31, 31,  │       512 │ conv2d[0][0]   │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add (Add)         │ (None, 31, 31,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │         0 │ add[0][0]      │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 31, 31,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 31, 31,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 16, 16,  │    32,768 │ add[0][0]      │   N   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 16, 16,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 16, 16,  │     1,024 │ conv2d_1[0][0] │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 16, 16,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │         0 │ add_1[0][0]    │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 16, 16,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 16, 16,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 8, 8,    │   186,368 │ add_1[0][0]    │   N   │
# │                   │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 8, 8,    │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 8, 8,    │     2,912 │ conv2d_2[0][0] │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 8, 8,    │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │         0 │ add_2[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_2[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │         0 │ add_3[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_3[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │         0 │ add_4[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_5 (Add)       │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_4[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │         0 │ add_5[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_6 (Add)       │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_5[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │         0 │ add_6[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_7 (Add)       │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_6[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │         0 │ add_7[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_8 (Add)       │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_7[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │         0 │ add_8[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_9 (Add)       │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_8[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │         0 │ add_9[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_10 (Add)      │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_9[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │         0 │ add_10[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 8, 8,    │   536,536 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │     2,912 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 8, 8,    │   752,024 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │     4,096 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 4, 4,    │   745,472 │ add_10[0][0]   │   N   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 4, 4,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 4, 4,    │     4,096 │ conv2d_3[0][0] │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_11 (Add)      │ (None, 4, 4,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 4, 4,    │ 1,582,080 │ add_11[0][0]   │   Y   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │     6,144 │ block14_sepco… │   Y   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 4, 4,    │ 3,159,552 │ block14_sepco… │   Y   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │     8,192 │ block14_sepco… │   Y   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss", start_from_epoch=10)

# %%
# last block unfrozen
model.compile(optimizer=keras.optimizers.Adam(1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

epochs=40
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.5008 - loss: 1.0200 - val_accuracy: 0.4909 - val_loss: 1.2232
# Epoch 2/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6268 - loss: 0.8089 - val_accuracy: 0.5146 - val_loss: 1.1412
# Epoch 3/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6393 - loss: 0.7500 - val_accuracy: 0.5202 - val_loss: 1.0972
# Epoch 4/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6449 - loss: 0.7094 - val_accuracy: 0.5411 - val_loss: 1.0683
# Epoch 5/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.6746 - loss: 0.6746 - val_accuracy: 0.5384 - val_loss: 1.0745
# Epoch 6/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.6819 - loss: 0.6671 - val_accuracy: 0.5411 - val_loss: 1.0331
# Epoch 7/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.6895 - loss: 0.6725 - val_accuracy: 0.5328 - val_loss: 1.0333
# Epoch 8/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - accuracy: 0.6833 - loss: 0.6543 - val_accuracy: 0.5523 - val_loss: 1.0661
# Epoch 9/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7088 - loss: 0.6172 - val_accuracy: 0.5244 - val_loss: 1.1456
# Epoch 10/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.7231 - loss: 0.6010 - val_accuracy: 0.5509 - val_loss: 1.0647
# Epoch 11/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - accuracy: 0.7390 - loss: 0.5968 - val_accuracy: 0.5286 - val_loss: 1.0517
# Epoch 12/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.7298 - loss: 0.5743 - val_accuracy: 0.5662 - val_loss: 1.0877
# Epoch 13/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7467 - loss: 0.5722 - val_accuracy: 0.5453 - val_loss: 1.0778
# Epoch 14/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7615 - loss: 0.5497 - val_accuracy: 0.5188 - val_loss: 1.1206
# Epoch 15/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7501 - loss: 0.5324 - val_accuracy: 0.5551 - val_loss: 1.0640
# Epoch 16/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.7726 - loss: 0.5224 - val_accuracy: 0.5425 - val_loss: 1.1634

# %%
plot_history(history)

# %%
pred_soft = model.predict(X_test)
preds = []
for i in pred_soft:
    preds.append(np.argmax(i))
print(classification_report(Y_test, preds))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61       224
#            1       0.50      0.51      0.51       296
#            2       0.68      0.45      0.54       198
#
#     accuracy                           0.55       718
#    macro avg       0.58      0.55      0.55       718
# weighted avg       0.57      0.55      0.55       718

# %%
cm = confusion_matrix(Y_test, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %% [markdown]
# ### Block 13

# %%
print(base_model.layers[-17])
print(base_model.layers[-16])
# Out:
# <Add name=add_10, built=True>
# <Activation name=block13_sepconv1_act, built=True>

# %%
# unfreeze entire exit flow block (16 layers)
for layer in base_model.layers[-16:]:
    layer.trainable = True
base_model.summary(show_trainable=True)
# Out:
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_2     │ (None, 128,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 128, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 63, 63,  │       864 │ input_layer_2… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 63, 63,  │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 63, 63,  │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 61, 61,  │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 61, 61,  │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 61, 61,  │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 61, 61,  │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 61, 61,  │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 61, 61,  │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d (Conv2D)   │ (None, 31, 31,  │     8,192 │ block1_conv2_… │   N   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 31, 31,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 31, 31,  │       512 │ conv2d[0][0]   │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add (Add)         │ (None, 31, 31,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │         0 │ add[0][0]      │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 31, 31,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 31, 31,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 31, 31,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 16, 16,  │    32,768 │ add[0][0]      │   N   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 16, 16,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 16, 16,  │     1,024 │ conv2d_1[0][0] │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 16, 16,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │         0 │ add_1[0][0]    │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 16, 16,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 16, 16,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 16, 16,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 8, 8,    │   186,368 │ add_1[0][0]    │   N   │
# │                   │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 8, 8,    │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 8, 8,    │     2,912 │ conv2d_2[0][0] │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 8, 8,    │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │         0 │ add_2[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 8, 8,    │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 8, 8,    │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 8, 8,    │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_2[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │         0 │ add_3[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 8, 8,    │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 8, 8,    │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 8, 8,    │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_3[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │         0 │ add_4[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 8, 8,    │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 8, 8,    │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_5 (Add)       │ (None, 8, 8,    │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_4[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │         0 │ add_5[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 8, 8,    │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 8, 8,    │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_6 (Add)       │ (None, 8, 8,    │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_5[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │         0 │ add_6[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 8, 8,    │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 8, 8,    │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_7 (Add)       │ (None, 8, 8,    │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_6[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │         0 │ add_7[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 8, 8,    │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 8, 8,    │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_8 (Add)       │ (None, 8, 8,    │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_7[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │         0 │ add_8[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 8, 8,    │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 8, 8,    │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_9 (Add)       │ (None, 8, 8,    │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_8[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │         0 │ add_9[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 8, 8,    │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 8, 8,    │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_10 (Add)      │ (None, 8, 8,    │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_9[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │         0 │ add_10[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 8, 8,    │   536,536 │ block13_sepco… │   Y   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 8, 8,    │     2,912 │ block13_sepco… │   Y   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 8, 8,    │   752,024 │ block13_sepco… │   Y   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 8, 8,    │     4,096 │ block13_sepco… │   Y   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 4, 4,    │   745,472 │ add_10[0][0]   │   Y   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 4, 4,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 4, 4,    │     4,096 │ conv2d_3[0][0] │   Y   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_11 (Add)      │ (None, 4, 4,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 4, 4,    │ 1,582,080 │ add_11[0][0]   │   Y   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │     6,144 │ block14_sepco… │   Y   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 4, 4,    │ 3,159,552 │ block14_sepco… │   Y   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │     8,192 │ block14_sepco… │   Y   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 4, 4,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_loss", start_from_epoch=10)

# %%
# exit flow unfrozen
model.compile(optimizer=keras.optimizers.Adam(1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

epochs=40
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callback)
# Out:
# Epoch 1/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 23s 192ms/step - accuracy: 0.7112 - loss: 0.6524 - val_accuracy: 0.5105 - val_loss: 1.3763
# Epoch 2/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.6952 - loss: 0.6452 - val_accuracy: 0.5202 - val_loss: 1.3824
# Epoch 3/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - accuracy: 0.7228 - loss: 0.6203 - val_accuracy: 0.5202 - val_loss: 1.3210
# Epoch 4/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.7493 - loss: 0.5893 - val_accuracy: 0.5230 - val_loss: 1.3340
# Epoch 5/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7198 - loss: 0.5986 - val_accuracy: 0.5328 - val_loss: 1.2298
# Epoch 6/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7327 - loss: 0.5945 - val_accuracy: 0.5230 - val_loss: 1.2489
# Epoch 7/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.7285 - loss: 0.6031 - val_accuracy: 0.5328 - val_loss: 1.2089
# Epoch 8/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7368 - loss: 0.5898 - val_accuracy: 0.5356 - val_loss: 1.1639
# Epoch 9/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.7389 - loss: 0.5644 - val_accuracy: 0.5537 - val_loss: 1.1554
# Epoch 10/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7653 - loss: 0.5541 - val_accuracy: 0.5495 - val_loss: 1.1032
# Epoch 11/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.7463 - loss: 0.5606 - val_accuracy: 0.5551 - val_loss: 1.1574
# Epoch 12/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7387 - loss: 0.5581 - val_accuracy: 0.5537 - val_loss: 1.1572
# Epoch 13/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.7598 - loss: 0.5379 - val_accuracy: 0.5272 - val_loss: 1.3265
# Epoch 14/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7703 - loss: 0.5464 - val_accuracy: 0.5342 - val_loss: 1.1991
# Epoch 15/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - accuracy: 0.7718 - loss: 0.5266 - val_accuracy: 0.5621 - val_loss: 1.1507
# Epoch 16/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7770 - loss: 0.5227 - val_accuracy: 0.5439 - val_loss: 1.1979
# Epoch 17/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7803 - loss: 0.5150 - val_accuracy: 0.5676 - val_loss: 1.1629
# Epoch 18/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7771 - loss: 0.5137 - val_accuracy: 0.5453 - val_loss: 1.2360
# Epoch 19/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.7608 - loss: 0.5376 - val_accuracy: 0.5621 - val_loss: 1.1527
# Epoch 20/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.7874 - loss: 0.4990 - val_accuracy: 0.5523 - val_loss: 1.2219

# %%
plot_history(history)

# %%
pred_soft = model.predict(X_test)
preds = []
for i in pred_soft:
    preds.append(np.argmax(i))
print(classification_report(Y_test, preds))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.63       224
#            1       0.47      0.60      0.53       296
#            2       0.75      0.26      0.39       198
#
#     accuracy                           0.54       718
#    macro avg       0.60      0.52      0.52       718
# weighted avg       0.58      0.54      0.52       718

# %%
cm = confusion_matrix(Y_test, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.tight_layout()

# %% [markdown]
# ## Analysis

# %%
import random
images = []
labels = []
for batch in test_dataset:
    image_batch, label_batch = batch
    images.append((image_batch.numpy() + 1) * 127.5)
    labels.append(label_batch.numpy())
X_test = np.concatenate(images)
y_test = np.concatenate(labels)

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
class_names = ['high', 'medium', 'low'] 

incorrect_indices = np.where(y_pred != y_test)[0]
print(len(incorrect_indices))

subset_size = 20
n_cols = 10
n_rows = subset_size // n_cols + 1 * (subset_size % n_cols)

subset_indices = random.sample(list(incorrect_indices), min(subset_size, len(incorrect_indices)))

plt.figure(figsize=(15, 6))

for i, incorrect in enumerate(subset_indices):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.imshow(X_test[incorrect].astype('uint8'))  # Assuming images are normalized
    plt.title(f"True: {class_names[y_test[incorrect]]}\nPred: {class_names[y_pred[incorrect]]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 478
